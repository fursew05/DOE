# %% [markdown]
# <a href="https://colab.research.google.com/github/fursew05/DOE/blob/main/%EC%8B%A4%ED%97%98%EA%B3%84%ED%9A%8D%EB%B2%95_1%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1장 - Introduction**

# %% [markdown]
# - DOE를 공부하는 이유?
#
#
# 1.   공정의 수율 혹은 성과를 향상시키기 위해서
# 2.   공정 품질 관리 (제품의 분산을 줄이기)
# 3.   강건성 달성
# 4.   시간과 비용을 절약하기 위해
#
# - 실험의 목적
#
# > 종속변수 y에 영향을 많이 주는 설명변수 x를 찾고 **어떻게 x를 두었을때 노이즈를 줄이면서 동시에 y의 분산을 줄일 수 있는지** 찾는 것임

# %% [markdown]
# # DOE를 진행하는 방법
#
#
#
# 1.   경험과 지식에 의한 설계 : 목적을 달성한다는 보장이 없음
# 2.   OFAT(한 요인에 대해서 한 실험을 진행) : 요인들간의 상호작용을 고려할 수 없음
# -  예를 들어, 다음과 같이 골프 점수에 영향을 주는 4가지 요인에 대해서 한 요인 마다 실험을 하는 경우의 결과를 보여줌. 각 요인에 따라 점수에 대한 차이가 존재하는지 확인할 수 있지만 운전자와 공의 상호작용으로 인한 점수차이가 있는지 확인하는 것을 불가능함
# ![image.png](data:image/png;base64,...)
# 3.   Factorial Design : 여러 요인을 함께 고려하여 설계
# - 다음 그림처럼 골프채의 사이즈와 음료수의 타입을 함께 고려하여 점수 차이가 어느 요인에서 발생하는지 확인할 수 있음. 위의 사진에서 드라이버의 크기에 따라 기울기가 존재했지만 Beverage Type과의 교호작용을 통해 기울기 변한 것을 확인할 수 있음
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -
